# %%
import pandas as pd
import numpy as np

import plotly

import plotly.graph_objs as go


import plotly.offline as offline

from plotly.graph_objs import *

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)

import plotly.graph_objects as go

init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
merge_csv = "Resources/merged_data/clean_merge2.csv"
merged_df = pd.read_csv(merge_csv, encoding="ISO-8859-1", low_memory=False, dtype={"FIPS": str})

# %%
merged_df.head()
# Out:
#     FIPS  Year      RegionName State                      Industry  \
# 0  01001  2009  Autauga County    AL            Federal Government
# 1  01001  2009  Autauga County    AL              State Government
# 2  01001  2009  Autauga County    AL              Local Government
# 3  01001  2009  Autauga County    AL               Goods-producing
# 4  01001  2009  Autauga County    AL  Natural resources and mining
#
#    Annual Average Establishment Count  Annual Average Employment  \
# 0                                  15                        100
# 1                                  16                        519
# 2                                  32                       1995
# 3                                 159                       1842
# 4                                  23                        197
#
#    Annual Total Wages  Annual Average Pay      Avg_Price
# 0             4476122               44873  144408.333333
# 1            18717293               36093  144408.333333
# 2            67539151               33857  144408.333333
# 3            91335147               49580  144408.333333
# 4             5506289               28022  144408.333333

# %%
#County_avg = merged_df.groupby(['Year','FIPS']).agg({'Avg_Price':'mean'})
County_avg = merged_df.groupby(['Year','FIPS']).mean()
#County_avg = merged_df.groupby(['Year','FIPS'])*merged_df.shape[1],axis=1).mean()
County_avg.head(100)
# Out:
#             Annual Average Establishment Count  Annual Average Employment  \
# Year FIPS
# 2009 01001                          113.000000                1293.066667
#      01003                          692.266667                7297.266667
#      01009                           99.333333                1009.466667
#      01017                           76.733333                 872.200000
#      01019                           49.866667                 563.266667
#      01021                           99.000000                 986.200000
#      01031                          138.266667                1790.200000
#      01033                          173.866667                2434.533333
#      01045                          114.333333                2056.733333
#      01047                          116.800000                1612.333333
#      01049                          157.133333                2520.533333
#      01051                          163.600000                2078.800000
#      01055                          278.400000                4125.266667
#      01069                          394.800000                5732.666667
#      01073                         2391.733333               41127.200000
#      01077                          265.133333                3594.933333
#      01081                          340.533333                5374.400000
#      01083                          171.866667                2331.733333
#      01089                         1153.333333               21277.733333
#      01097                         1288.333333               20319.466667
#      01101                          829.066667               15110.000000
#      01103                          364.133333                5561.466667
#      01109                           95.066667                1619.666667
#      01113                          115.400000                1478.933333
#      01115                          175.866667                1890.266667
#      01117                          639.600000                8922.000000
#      01121                          178.000000                3127.066667
#      01123                          111.400000                1569.666667
#      01125                          568.400000                9524.466667
#      01127                          188.400000                2227.866667
# ...                                        ...                        ...
#      05113                           73.866667                 755.666667
#      05115                          234.466667                3170.000000
#      05119                         1974.466667               28965.733333
#      05121                           54.733333                 570.733333
#      05125                          246.066667                2451.333333
#      05131                          513.200000                8585.733333
#      05135                           56.800000                 422.000000
#      05139                          181.333333                2269.200000
#      05143                          740.800000               10839.933333
#      05145                          242.533333                3087.133333
#      05149                           57.000000                 751.333333
#      06001                         6571.875000               73725.562500
#      06005                          127.250000                1220.312500
#      06007                          953.937500                8068.812500
#      06009                          159.375000                 828.250000
#      06011                           96.625000                 876.375000
#      06013                         3648.250000               37119.000000
#      06017                          618.187500                5375.187500
#      06029        1.154149e+09        41434.875000  148166.666667
#      06031        1.476036e+08        35583.562500  162775.000000
#      06033        5.084931e+07        33527.937500  173308.333333
#      06037        2.311865e+10        55108.687500  394466.666667
#      06039        1.645686e+08        35685.062500  149825.000000
#      06041        6.608830e+08        55869.562500  719600.000000
#      06043        1.503323e+07        31095.375000  152900.000000
#
# [100 rows x 5 columns]

# %%
fig = go.Figure(go.Choroplethmapbox(geojson=counties, locations=merged_df.FIPS, z=merged_df.Avg_Price,
                                    colorscale="Viridis", zmin=0, zmax=12,
                                    marker_opacity=0.5, marker_line_width=0))
fig.update_layout(mapbox_style="carto-positron",
                  mapbox_zoom=3, mapbox_center = {"lat": 37.0902, "lon": -95.7129})
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %%
data_slider = []

for year in merged_df.Year.unique():
        df_price = merged_df[(merged_df['Year']== year)]
        fig = go.Figure(go.Choroplethmapbox(geojson=counties, locations=df_price.FIPS, z=df_price.Avg_Price,
                                    colorscale="Viridis", zmin=0, zmax=12,
                                    marker_opacity=0.5, marker_line_width=0))
        fig.update_layout(mapbox_style="carto-positron",
                          mapbox_zoom=3, mapbox_center = {"lat": 37.0902, "lon": -95.7129})
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        data_slider.append(fig) 
        fig.show()

# %%
# scl = [[0.0, '#ffffff'],[0.2, '#ff9999'],[0.4, '#ff4d4d'], 
#        [0.6, '#ff1a1a'],[0.8, '#cc0000'],[1.0, '#4d0000']] 

# data_slider = []

# for year in merged_df.Year.unique():
    
#     df_price = merged_df[(merged_df['Year']== year)]

#     for col in df_price.columns:
#         df_price[col] = df_price[col].astype(str)

#     df_price['text'] = df_price['RegionName']#+'Avg_Price: 'df_price['Avg_Price']
    
#     data_one_year = dict(
#                         type='choropleth',
#                         locations = df_price['FIPS'],
#                         z=df_price['Avg_Price'].astype(float),
#                         #locationmode='USA-states',
#                         colorscale = scl,
#                         text = df_price['text'],
#                         )

#     data_slider.append(data_one_year)

# %%
steps = []

for i in range(len(data_slider)):
    step = dict(method='restyle',
                args=['visible', [False] * len(data_slider)],
                label='Year {}'.format(i + 2009)) # label to be displayed for each step (year)
    step['args'][1][i] = True
    steps.append(step)
    
sliders = [dict(active=0, pad={"t": 1}, steps=steps)] 

# fig.update_layout(mapbox_style="carto-positron",
#                   mapbox_zoom=3, mapbox_center = {"lat": 37.0902, "lon": -95.7129})
# fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})

fig = dict(data=data_slider, layout=layout) 

plotly.offline.iplot(fig)

# %%
# data = [ dict(
#             type='choropleth', # type of map-plot
#             colorscale = scl,
#             autocolorscale = False,
#             locations = df_price['FIPS'], # the column with the state
#             z = df_price['Avg_Price'].astype(float), # the variable I want to color-code
#             #locationmode = 'USA-states',
#             text = df_price['text'], # hover text
#             marker = dict(     # for the lines separating states
#                         line = dict (
#                                   color = 'rgb(255,255,255)', 
#                                   width = 2) ),               
#             colorbar = dict(
#                         title = "Average Price by County")
#             ) 
#        ]

# layout = dict(
#         title = year,
#         geo = dict(
#             scope='usa',
#             projection=dict( type='albers usa' ),

# #              showlakes = True,  # if you want to give color to the lakes

# #             lakecolor = 'rgb(73, 216, 230)'  
#             ),
#              )


# fig = dict( data=data, layout=layout )
# plotly.offline.iplot(fig)
