# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Pull in file 
merged_df = pd.read_csv('Resources/merged_data/clean_merge.csv')



merged_df.head()
# Out:
#    FIPS  St  Cnty  NAICS  Year Area Type  St Name                     Area  \
# 0  1001   1   1.0     10  2009    County  Alabama  Autauga County, Alabama
# 1  1001   1   1.0     10  2009    County  Alabama  Autauga County, Alabama
# 2  1001   1   1.0     10  2009    County  Alabama  Autauga County, Alabama
# 3  1001   1   1.0     10  2009    County  Alabama  Autauga County, Alabama
# 4  1001   1   1.0     10  2009    County  Alabama  Autauga County, Alabama
#
#                 Industry  Annual Average Employment  Annual Average Pay  \
# 0  Total, all industries                      11004               31232
# 1  Total, all industries                        100               44873
# 2  Total, all industries                        519               36093
# 3  Total, all industries                       1995               33857
# 4  Total, all industries                       8391               30145
#
#    Total Wage Location Quotient Relative to U.S.      RegionName State  \
# 0                                           1.00  Autauga County    AL
# 1                                           0.40  Autauga County    AL
# 2                                           1.41  Autauga County    AL
# 3                                           1.88  Autauga County    AL
# 4                                           0.89  Autauga County    AL
#
#    Avg_Price
# 0  144408.33
# 1  144408.33
# 2  144408.33
# 3  144408.33
# 4  144408.33

# %%
industry_group = merged_df.groupby(['Year', 'State', 'Industry'])
avg_pay = industry_group["Annual Average Pay"].mean()
avg_pay = pd.DataFrame(avg_pay).reset_index()
avg_pay.head()
# Out:
#    Year State                       Industry  Annual Average Pay
# 0  2009    AK                   Construction           54798.500
# 1  2009    AK  Education and health services           39387.625
# 2  2009    AK           Financial activities           43685.250
# 3  2009    AK                Goods-producing           59767.750
# 4  2009    AK                    Information           46270.250

# %%
avg_year = avg_pay.groupby(['Year','Industry'])
avg_byYear = avg_year['Annual Average Pay'].mean()

avg_byYear = pd.DataFrame(avg_byYear).reset_index()
avg_byYear['Industry'] = avg_byYear['Industry'].str.replace('\d+', '')
avg_byYear['Industry'] = df1['State'].str.strip()
avg_byYear
# Out:
#      Year                               Industry  Annual Average Pay
# 0    2009                           Construction        39285.369550
# 1    2009          Education and health services        35434.768980
# 2    2009                   Financial activities        42451.262191
# 3    2009                        Goods-producing        43982.154482
# 4    2009                            Information        40938.983910
# 5    2009                Leisure and hospitality        14678.083955
# 6    2009                          Manufacturing        43288.780069
# 7    2009           Natural resources and mining        34532.830603
# 8    2009                         Other services        24319.188734
# 9    2009     Professional and business services        40716.435795
# 10   2009                      Service-providing        32382.214451
# 11   2009                  Total, all industries        40278.177946
# 12   2009   Trade, transportation, and utilities        31272.850133
# 13   2009                           Unclassified        33049.426298
# 14   2010                           Construction        40094.538994
# 15   2010          Education and health services        36164.594138
# 16   2010                   Financial activities        44063.921085
# 17   2010                        Goods-producing        45576.013102
# 18   2010                            Information        42086.219923
# 19   2010                Leisure and hospitality        15221.368226
# 20   2010                          Manufacturing        44779.199978
# 21   2010           Natural resources and mining        35923.571776
# 22   2010                         Other services        24713.300148
# 23   2010     Professional and business services        41779.600947
# 24   2010                      Service-providing        33202.709762
# 25   2010                  Total, all industries        40597.320273
# 26   2010   Trade, transportation, and utilities        32021.648002
# 27   2010                           Unclassified        31825.689645
# 28   2011                           Construction        41295.400186
# 29   2011          Education and health services        36678.963506
# ..    ...                                    ...                 ...
# 110  2016   Trade, transportation, and utilities        36450.497345
# 111  2016                           Unclassified        33680.932922
# 112  2017                  Total, all industries        47297.416388
# 113  2017                        Goods-producing        53373.701789
# 114  2017           Natural resources and mining        41852.554108
# 115  2017                           Construction        46879.931213
# 116  2017                          Manufacturing        51912.995371
# 117  2017                      Service-providing        39073.755295
# 118  2017   Trade, transportation, and utilities        37504.206134
# 119  2017                            Information        50301.801471
# 120  2017                   Financial activities        55644.237029
# 121  2017     Professional and business services        50122.535003
# 122  2017          Education and health services        41403.159295
# 123  2017                Leisure and hospitality        18067.952820
# 124  2017                         Other services        30077.674503
# 125  2017                           Unclassified        40406.638545
# 126  2018                  Total, all industries        49002.864843
# 127  2018                        Goods-producing        54522.599359
# 128  2018           Natural resources and mining        43998.784922
# 129  2018                           Construction        49846.704373
# 130  2018                          Manufacturing        52898.349113
# 131  2018                      Service-providing        40091.302144
# 132  2018   Trade, transportation, and utilities        38719.243492
# 133  2018                            Information        51987.580602
# 134  2018                   Financial activities        57753.547360
# 135  2018     Professional and business services        51735.452040
# 136  2018          Education and health services        42753.996872
# 137  2018                Leisure and hospitality        18668.216302
# 138  2018                         Other services        30967.686845
# 139  2018                           Unclassified        47658.548520
#
# [140 rows x 3 columns]

# %%
                     
print(avg_byYear[avg_byYear['Industry'] == ' Leisure and hospitality'])
# Out:
#      Year                  Industry  Annual Average Pay
# 123  2017   Leisure and hospitality        18067.952820
# 137  2018   Leisure and hospitality        18668.216302

# %%
# Line graph, salary over 2009-2019 by industry 


goods = avg_byYear.loc[avg_byYear['Industry'] == "Goods-producing", "Annual Average Pay"]
print(goods)
natural_resources = avg_byYear.loc[avg_byYear['Industry'] == "Natural resources and mining", "Annual Average Pay"]
#print(natural_resources)
construction = avg_byYear.loc[avg_byYear['Industry'] == "Construction", "Annual Average Pay"]
manufacturing = avg_byYear.loc[avg_byYear['Industry'] == "Manufacturing", "Annual Average Pay"]
service = avg_byYear.loc[avg_byYear['Industry'] == "Service-providing", "Annual Average Pay"]
trade_transportation_utilities = avg_byYear.loc[avg_byYear['Industry'] == "Trade, transportation, and utilites", "Annual Average Pay"]
information = avg_byYear.loc[avg_byYear['Industry'] == "Information", "Annual Average Pay"]
finance = avg_byYear.loc[avg_byYear['Industry'] == "Financial activities", "Annual Average Pay"]
business = avg_byYear.loc[avg_byYear['Industry'] == "Professional and business services", "Annual Average Pay"]
education_health = avg_byYear.loc[avg_byYear['Industry'] == "Education and health services ", "Annual Average Pay"]
leisure = avg_byYear.loc[avg_byYear['Industry'] == "Leisure and hospitality", "Annual Average Pay"]
other = avg_byYear.loc[avg_byYear['Industry'] == "Other services", "Annual Average Pay"]
unclassified = avg_byYear.loc[avg_byYear['Industry'] == "Unclassified", "Annual Average Pay"]

#years = [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2018, 2019]
years = [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]
# #plt.plot(years, avg_byYear.loc["Goods-producing", ["2009","2010","2011","2012","2013, 2014, 2015, 2016, 2017, 2018"]], 
# #                        color="green",label=avg_byYear.loc["Goods-producing","Industry"])

plt.plot(years, goods, label= "Goods-producing", marker= "o", color= "red", linestyle='--')
# plt.plot(years, natural_resources, label= "Natural resources and mining", marker= "^", color= "blue", linestyle='--')
# plt.plot(years, construction, label= "Construction", marker= "o", color= "black", linestyle='--')
# plt.plot(years, manufacturing, label= "Manufacturing", marker= "^", color= "green", linestyle='--')

plt.show()


#
# Out:
# 3      43982.154482
# 17     45576.013102
# 31     46656.501962
# 45     47941.426089
# 59     48824.715506
# 73     50458.150561
# 87     51289.818670
# 101    51788.649798
# Name: Annual Average Pay, dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-aaed60a59c14> in <module>
# ----> 1 print(goods)
#
# NameError: name 'goods' is not defined
