# %%
import pandas as pd
import glob

# %%
#Defining my data sources. Data sources include two CSV files derived from BLS and Zillow.
bls_csv = "Resources/BLSData/Bls_concat.csv"
zillow_csv = "Resources/Zillow_Data/County_Zhvi_AllHomes.csv"

# %%
#Reading my data sources. In this case, my csv files.
bls_df = pd.read_csv(bls_csv)
zillow_df = pd.read_csv(zillow_csv, encoding = "latin-1", low_memory=False)
# Out:
# /Users/hannahtate/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1,2,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Print BLS csv.
bls_df.head()
# Out:
#    Unnamed: 0 Area\nCode  St  Cnty  Own  NAICS  Year Qtr Area Type St Name  \
# 0           0      US000  US   0.0    0     10  2009   A    Nation     NaN
# 1           1      US000  US   0.0    1     10  2009   A    Nation     NaN
# 2           2      US000  US   0.0    2     10  2009   A    Nation     NaN
# 3           3      US000  US   0.0    3     10  2009   A    Nation     NaN
# 4           4      US000  US   0.0    5     10  2009   A    Nation     NaN
#
#    ...           Ownership               Industry Annual Average Status Code  \
# 0  ...       Total Covered  Total, all industries                        NaN
# 1  ...  Federal Government  Total, all industries                        NaN
# 2  ...    State Government  Total, all industries                        NaN
# 3  ...    Local Government  Total, all industries                        NaN
# 4  ...             Private  Total, all industries                        NaN
#
#   Annual Average Establishment Count  Annual Average Employment  \
# 0                            9003197                  128607842
# 1                              65581                    2826713
# 2                              67075                    4639715
# 3                             161427                   14194311
# 4                            8709115                  106947104
#
#    Annual Total Wages  Annual Average Weekly Wage  Annual Average Pay  \
# 0        5.859230e+12                         876               45559
# 1        1.915280e+11                        1303               67756
# 2        2.261490e+11                         937               48742
# 3        6.123440e+11                         830               43140
# 4        4.829210e+12                         868               45155
#
#    Employment Location Quotient Relative to U.S.  \
# 0                                            1.0
# 1                                            1.0
# 2                                            1.0
# 3                                            1.0
# 4                                            1.0
#
#    Total Wage Location Quotient Relative to U.S.
# 0                                            1.0
# 1                                            1.0
# 2                                            1.0
# 3                                            1.0
# 4                                            1.0
#
# [5 rows x 21 columns]

# %%
#Print Zillow csv.
zillow_df.head()
# Out:
#    RegionID          RegionName State                             Metro  \
# 0      3101  Los Angeles County    CA    Los Angeles-Long Beach-Anaheim
# 1       139         Cook County    IL          Chicago-Naperville-Elgin
# 2      1090       Harris County    TX  Houston-The Woodlands-Sugar Land
# 3      2402     Maricopa County    AZ           Phoenix-Mesa-Scottsdale
# 4      2841    San Diego County    CA                San Diego-Carlsbad
#
#    StateCodeFIPS  MunicipalCodeFIPS   FIPS  SizeRank   1996-04   1996-05  ...  \
# 0              6                 37   6037         1  160800.0  160700.0  ...
# 1             17                 31  17031         2  133400.0  134300.0  ...
# 2             48                201  48201         3   97900.0   97800.0  ...
# 3              4                 13   4013         4  108500.0  108900.0  ...
# 4              6                 73   6073         5  163800.0  163400.0  ...
#
#    2018-12  2019-01  2019-02  2019-03  2019-04  2019-05  2019-06  2019-07  \
# 0   619600   622100   624000   623500   622100   621800   621200   620900
# 1   223300   224000   225400   226600   226200   224900   224000   223500
# 2   188300   189600   191200   191500   190700   190500   191700   192800
# 3   270600   272300   273800   274300   274500   274900   274700   275300
# 4   593100   592700   592700   592700   593200   593300   593000   592900
#
#    2019-08  2019-09
# 0   622300   624900
# 1   223200   223300
# 2   193300   193800
# 3   277200   278800
# 4   593000   593700
#
# [5 rows x 290 columns]

# %%
#Merging both zillow and bls data frames into one data frame
merge_df = pd.merge(bls_df, zillow_df, on="FIPS")
#merge_df = 
merge_df.head()

# %%
#Renaming columns.
merge_df_rename = merge_df_rename.rename(columns={})

#These are columns we want to incorporate from the zillow dataframe. 
#Year
#Avg_Home_Price
